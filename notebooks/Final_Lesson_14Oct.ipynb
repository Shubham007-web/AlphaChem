# %%
import openai
from docx import Document
import re   # just number extracting from unit, chapter and lesson

# %%
# Set your OpenAI API key
api_key = "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"  # Replace with your actual API key

# %%
openai.api_key = api_key  # Replace with your actual API key

# %%
# function to handle chat-basd content genration

def generate_content_with_chat(messages):
    response = openai.ChatCompletion.create(
        model = 'chatgpt-4o-latest',
        messages = messages,
        max_tokens = 10000,
        temperature = 0.7 )
    return response['choices'][0]['message']['content'].strip()

# %%
# generate_content_with_chat("Hello, how are you?")

# %%
reading_score = ''' Please follow these formula in order to genrate content. Flesch Reading Ease Score >= 80, and grade level 8
1. Flesch Reading Ease Score = 206.835 − 1.015 × ( Total Words / Total Sentences ) − 84.6 × ( Total Syllables / Total Words )
2. Flesch-Kincaid Grade Level = 0.39 × ( Total Words / Total Sentences ) + 11.8 × ( Total Syllables / Total Words ) − 15.59
'''

# %%
lesson_objective = '''Describe how ions are formed.
 Write the symbols and charges of ions and  octect rule and its expeceptions
 Predict the charge of an ion based on its position on the periodic table.'''

# %%
lesson_vocabulary = '''Octet Rule
 Anion
 Cation
 Electrolyte
 Electron affinity
 Ionic radius
 Ionization
 Octet rule
 '''

Essential_Question  = '''How are ions formed, and what role do they play in chemical bonding?'''

Performance_Expectations = '''HS-PS1-2: Construct and revise an explanation for the outcome of a simple chemical reaction based on the outermost electron states of atoms, trends in the periodic table, and knowledge of the patterns of chemical properties.'''

Disciplinary_Core_Ideas = '''PS1.A: Structure and Properties of Matter The structure and interactions of matter at the bulk scale are determined by electrical forces within and between atoms.'''

# %%
phenomenon = '''Unit phenomenon: Danger! Icy Roads
In northern countries, where winter brings extremely cold weather, streets and roads are often covered in ice and snow. This creates hazardous conditions for both pedestrians and drivers. Pedestrians can slip and fall, risking injury, while cars may skid on the icy surfaces, potentially causing accidents. To reduce these dangers, road salt is spread on icy streets to help melt the ice and snow. As the salt comes into contact with the ice, ice and snow seem to vanish. Metal street signs and lampposts are also exposed to the same ice and snow, but they do not vanish.
Chapter Phenomenon: Salt vs. Metal, Why Does Water Treats Them Differently?
When road salt is spread on icy and snowy streets, the ice and snow melt and the salt dissolves in the water. Street signs and lampposts are made of metal, but they do not melt the snow or dissolve in water. Instead, they remain intact, showing no immediate signs of rust or corrosion. Why do salt and metal behave so differently with water?
'''

# %%
# # Prompt 2.2 - SB Lesson Structure
# def lesson_prompt_template(unit_name, chapter_name, lesson_name,  Essential_Question, lesson_vocabulary, lesson_objective, phenomenon):
#     return f"""
#     Generate comprehensive content for Lesson "{lesson_name}" under Chapter "{chapter_name}" of Unit "{unit_name}".
#     The content should be structured, consistent, and align with the following points:
#      - lesson objective: {lesson_objective}
#      - lesson_vocabulary : {lesson_vocabulary}
#      - Essential_Question : {Essential_Question}
#      - Performance_Expectations : {Performance_Expectations}
#      - Disciplinary_Core_Ideas : {Disciplinary_Core_Ideas}
     
#     ## Unit Title
#     ## Chapter Title
#     # Lesson Title
#     ### Essential Questions:
#      Write the following Essential Questions (EQs) to ensure they drive curiosity and critical thinking:
#     - {Essential_Question}

#     ### Big Idea:
#     - One line, which addresses the main concept of the lesson.
#     - A subordinate of the Chapter's Big Idea that addresses the main concepts in the lesson.

#     ### Essential Questions:
#     Write the following Essential Questions (EQs) to ensure they drive curiosity and critical thinking:
#     - {Essential_Question}
#     - These questions should spark curiosity, promote critical thinking, and encourage further exploration.

#     ### Phenomenon-Based Learning:
#     The lesson should build upon the chapter's storyline and introduce a specific aspect, question, or issue that will be explored through hands-on tasks. Focus on connecting the phenomenon to the lesson's tasks and investigations.
#     - Phenomenon: {phenomenon}

#     ### Vocabulary:
#     Provide definitions for the key terms in the lesson. Ensure students understand these terms, as they will be essential to grasping the main concepts.
#     - {lesson_vocabulary}

#     ### SMART Lesson Objectives:
#     The following are 3-4 Specific, Measurable, Achievable, Relevant, and Time-based (SMART) as given only learning objectives:
#     - {lesson_objective}
#     - These should target both content knowledge and skills, with progressively higher levels of complexity aligned to Bloom’s Taxonomy.
#     - Avoid vague verbs like "understand" or "know". Use measurable action verbs such as "apply," "analyze," or "create."

#     ### Ignite (Engage) :
#     - Introduce the lesson with a phenomenon-related question or simple task that grabs students’ attention.
#     - The task does not need to be rigorous or assessed but should be inclusive for all students (consider students with impairments). 
#     - Assume that student has AI tool, and based on that Include the introduction of AI at least once per chapter through an inquiry-based task to encourage students to ask questions about the lesson's topic.

#     ### Direct Instruction (Pre-Explore Section) [Approx. 500 words]:
#     - Provide background information to build student understanding of the topic before moving to hands-on activities.
#     - Avoid long passages of text without interactive elements (e.g., asking students to take notes, discuss observations, or answer scaffolded questions).
#     - Relate content to the phenomenon, extracting examples to strengthen the storyline.

#     ### Progress Check (Evaluate) [Approx. 200 words]:
#     - Include up to 3 scaffolded questions (DOK Levels 1, 2, and 3) to ensure students can connect procedures to the content in the "Explore" section.
#     - These should help students reflect on the lesson so far and guide them towards the next step.

#     ### Pathfinder (Explore) [Hands-On Section, Approx. 1000 words]:
#     - You can take a lab experiment as well, then ask the questions based on observation, (e.g. like what and why happend...)
#     - Provide step-by-step instructions for the hands-on activity, ensuring students collect and analyze data.
#     - Encourage students to engage in group discussions and collaborative learning.
#     - Use prompts that guide critical analysis of data and help students draw conclusions connecting the inquiry to the phenomenon.
#     - Incorporate **Retrieval Practice** by adding questions or quizzes during or after the activity to ensure knowledge recall from previous lessons.

#     ### Lightbulb (Explain) [Minds-On Section, Approx. 3000 words]:
#     - Please remember this consist main content of the lesson and the content should be agline with stroyline too.
#      - Provide a structured and detailed explanation of the key concepts related to the lesson.
#      - Ensure coherence with the chapter's content and key objectives.
#      - Include relevant examples, case studies, or real-world applications to illustrate the concepts.
#      - Break down complex ideas into easily digestible sections or subsections.
#      - Incorporate any relevant formulas, algorithms, or theoretical foundations.
#      - If applicable, discuss any ethical considerations or potential impacts of the topic.
#      - Include at least one visual aid (e.g., a diagram, flowchart, or table) to support the explanation.
#     - Provide prompts that help students make sense of the hands-on activity by applying prior knowledge and discussing results.
#     - Expand on the key concepts explored in the "Explore" section, linking back to the lesson's SMART objectives.
#     - For every major concept, include one solved example problem followed by a question for students to solve as a Progress Check.
#     - Reinforce student understanding with discussions or guided problem-solving.

#     ### Progress Check (Evaluate) [Approx. 300 words]:
#     - Pose up to 3 scaffolded questions (DOK Levels 1, 2, and 3) related to the Explain section to confirm understanding of the main concepts.

#     ### Power Up (Elaborate) [Approx. 500 words]:
#     - Introduce mini-tasks or open-ended questions that encourage students to think critically and relate lesson content to the chapter phenomenon.
#     - Include opportunities for students to ask further questions, using the Questioneer to expand their understanding.

#     ### Progress Check (Final Evaluation) [Approx. 800 words]:
#     * Frame 1 detailed debate questions that encourage critical thinking and application of the learned concepts in the lesson. The Question should have:
#     - A clear prompt
#     - Potential arguments for multiple viewpoints
#     - Suggested points for discussion
#     * Provide 8 assessment questions:
#     - 4 multiple-choice questions with 4 options each, including the correct answer and plausible distractors
#     - 4 long-answer questions that require application of knowledge and higher-order thinking skills
#     The alignment of questions must be uniform. MCQs and LA questions should be placed properly like all MCQs are placed first and then followed by LA Questions. More questions can be added.

#     - Ensure all questions align with the unit learning outcomes and the content provided in the "Engage" and "Explain" sections.
    
#     ### Beyond the Lesson (Extend) [Optional, Approx. 400 words]:
#     - Introduce additional tasks, readings, or challenges that encourage students to apply their knowledge to real-world problems.
#     - Provide opportunities for spaced practice, reinforcing key concepts over time to improve long-term retention.
#     """

# %%
def lesson_prompt_template(unit_name, chapter_name, lesson_name, essential_question, lesson_vocabulary, lesson_objectives, phenomenon):
    return f"""
    Generate a detailed and structured lesson plan for "{lesson_name}" in Chapter "{chapter_name}" of Unit "{unit_name}".
    The content should be structured, consistent, and align with the following points:
     - lesson objective: {lesson_objective}
     - lesson_vocabulary : {lesson_vocabulary}
     - Essential_Question : {Essential_Question}
     - Performance_Expectations : {Performance_Expectations}
     - Disciplinary_Core_Ideas : {Disciplinary_Core_Ideas}
     
    ## Unit Title
    ## Chapter Title
    # Lesson Title
    ### Essential Questions:
     Write the following Essential Questions (EQs) to ensure they drive curiosity and critical thinking:
    - {Essential_Question}

    ### 1. Big Idea:
    - One line, which addresses the main concept of the lesson.
    - A subordinate of the Chapter's Big Idea that addresses the main concepts in the lesson.

    ### 2. Essential Questions
    - Include the following Essential Question(s) to encourage critical thinking:
        - {essential_question}

    ### 3. Phenomenon-Based Learning
    - The lesson should build upon the chapter's storyline and introduce a specific aspect, question, or issue that will be explored through hands-on tasks. Focus on connecting the phenomenon to the lesson's tasks and investigations.
    - Phenomenon: {phenomenon}

    ### 4. Vocabulary
    - Define these key terms to support students’ understanding:
        - {lesson_vocabulary}

    ### 5. SMART Objectives
    - List 3-4 Specific, Measurable, Achievable, Relevant, Time-based objectives those are in lesson objective:
        - {lesson_objectives}

    ### 6. Engage (Ignite)
    - Start with a phenomenon-related question or task to grab attention and contitnue on the same story.
    - Include one hands-on experiment relevant to the lesson topic, with a step-by-step procedure.
    - Add 2-3 follow-up questions based on the activity.

    ### 7. Pre-Explore (Direct Instruction)
    - Provide background information linking the phenomenon and key concepts.
    - Use interactive elements (notes, discussions, scaffolded questions) to break up the content.

    ### 8. Evaluate (Progress Check) - Pre-Explore
    - Frame up to 3 scaffolded questions (DOK 1-3) to connect concepts to the hands-on activity.

    ### 9. Explore (Pathfinder)
    - Guide students through a hands-on activity with clear instructions.
    - Ensure they collect data and engage in group discussions.
    - Use retrieval practice (quizzes or questions) to reinforce learning.

    ### 10. Explain (Lightbulb) 
    - Please remember this section content should around 4500 words, that explain core and main concept of the lesson based stroyline.
    - Provide a comprehensive and detailed explanation of the main ideas related to the lesson, spanning approximately 4000-5000 words.
    - Ensure content follows the unit and chapter storyline Phenomenon: {phenomenon}, aligning with thelesson objective: {lesson_objective}and the Big Idea.
    - Break down complex concepts into structured sections or subsections, making them easily digestible and go deep for 14-15 years old 4-5 pages long.
    - Write prompts to help students make sense of the hands-on activity by themselves, based on their prior knowledge, the evidence they gathered in their inquiry activities, and discussions with the classmates.
    - After students made their attempt, provide expansion of concepts explored in the Explore section to build a tight connection to the lessons’ LOs.  
    - For every main concept explained, one sample solved problem is introduced where applicable and then one question for students to solve as a Progress Check.


    ### 11. Evaluate (Progress Check) - Explain
    - Include 3 scaffolded questions (DOK 1-3) to confirm understanding of key concepts covered in the Explain section.

    ### 12. Elaborate (Power Up)
    - Pose mini-tasks or open-ended questions encouraging deeper thinking.
    - Allow space for additional questions to extend understanding.

    ### 13. Final Evaluation
    - Provide 1 debate question, including arguments and points for discussion.
    - Frame 8 assessment questions:
        - 4 multiple-choice questions (with options and correct answers).
        - 4 long-answer questions requiring application of knowledge.
    - Ensure alignment with the unit learning outcomes.

    ### 14. Extend (Beyond the Lesson) [Optional]
    - Suggest additional tasks, readings, or challenges related to the lesson.
    - Activities (could include readings) and/or questions that challenge students to think about the application of what they’ve learned to new real-world situations, applications, or problems enhancing their understanding of the chapter and unit tasks.
    - Set up the stage for future lessons. 
    - Provide opportunities for spaced practice, i.e. students review and reinforce previously learned key concepts, allowing students to revisit and reinforce their understanding over time. Spaced practice involves distributing practice and review sessions across several days or weeks to improve long-term retention of material.

    """

# %%
def generate_lesson_content(unit_name, chapter_name, lesson_name, lesson_objective):
    messages = [
        {"role": "system", "content": f"You are a chemistry textbook writer for age 14-15 years, and content should be easy to read for this please use these formula {reading_score} to make easy languge to read and that should greater 90, generated in a way that feels like it's written by a human and target audience is USA school grade 9."},
        {"role": "user", "content": lesson_prompt_template(unit_name, chapter_name, lesson_name,  Essential_Question, lesson_vocabulary, lesson_objective, phenomenon)}
    ]

    # Generate the content using OpenAI's GPT model
    return generate_content_with_chat(messages)

# Function to extract numbers from unit, chapter, and lesson names for file naming
def extract_number(text):
    return re.search(r'\d+', text).group()

# Function to save the generated content to a .docx file with the specific naming format
def save_lesson_content_to_docx(unit_name, chapter_name, lesson_name, lesson_content):
    # Create a new document
    doc = Document()
    doc.add_heading(f'Unit: {unit_name}', level=1)
    doc.add_heading(f'Chapter: {chapter_name}', level=2)
    doc.add_heading(f'Lesson: {lesson_name}', level=3)

    # Add the generated content to the document
    doc.add_paragraph(lesson_content)

    # Extract unit, chapter, and lesson numbers from their names for the file name
    unit_number = extract_number(unit_name)
    chapter_number = extract_number(chapter_name)
    lesson_number = extract_number(lesson_name)

    # Construct the file name in the format U1Ch1L4.docx
    file_name = f'U{unit_number}Ch{chapter_number}L{lesson_number}.docx'

    # Save the document with the constructed file name
    doc.save(file_name)
    print(f'Content saved to {file_name}')

# %%
# Example usage to generate and save lesson content
unit_name = "Unit 2: Atomic Structure and Bonding"
chapter_name = "Chapter 6: Ionic and Metallic Bonding"
lesson_name = "Lesson 1: Formation and Properties of Ions"

# Generate detailed content for Engage, Explain, and Evaluate sections
lesson_content = generate_lesson_content(unit_name, chapter_name, lesson_name,lesson_objective)

# Print the generated content (optional)
print(lesson_content)

# Save the generated content to a .docx file in the format U1Ch1L4.docx
save_lesson_content_to_docx(unit_name, chapter_name, lesson_name, lesson_content)
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[13], line 7
#       4 lesson_name = "Lesson 1: Formation and Properties of Ions"
#       6 # Generate detailed content for Engage, Explain, and Evaluate sections
# ----> 7 lesson_content = generate_lesson_content(unit_name, chapter_name, lesson_name,lesson_objective)
#       9 # Print the generated content (optional)
#      10 print(lesson_content)
#
# Cell In[12], line 8, in generate_lesson_content(unit_name, chapter_name, lesson_name, lesson_objective)
#       2 messages = [
#       3     {"role": "system", "content": f"You are a chemistry textbook writer for age 14-15 years, and content should be easy to read for this please use these formula {reading_score} to make easy languge to read and that should greater 90, generated in a way that feels like it's written by a human and target audience is USA school grade 9."},
#       4     {"role": "user", "content": lesson_prompt_template(unit_name, chapter_name, lesson_name,  Essential_Question, lesson_vocabulary, lesson_objective, phenomenon)}
#       5 ]
#       7 # Generate the content using OpenAI's GPT model
# ----> 8 return generate_content_with_chat(messages)
#
# Cell In[4], line 4, in generate_content_with_chat(messages)
#       3 def generate_content_with_chat(messages):
# ----> 4     response = openai.ChatCompletion.create(
#       5         model = 'chatgpt-4o-latest',
#       6         messages = messages,
#       7         max_tokens = 10000,
#       8         temperature = 0.7 )
#       9     return response['choices'][0]['message']['content'].strip()
#
# File ~/shubham/AlphaChem/.venv/lib/python3.9/site-packages/openai/lib/_old_api.py:39, in APIRemovedInV1Proxy.__call__(self, *_args, **_kwargs)
#      38 def __call__(self, *_args: Any, **_kwargs: Any) -> Any:
# ---> 39     raise APIRemovedInV1(symbol=self._symbol)
#
# APIRemovedInV1:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
